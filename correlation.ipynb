# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Child development researchers studying growth patterns of children collect data on the height of fathers and sons.
#
# Analyse the correlation between the father's height and their son's height using the given data
#
# Father Height = [169.39, 161.91, 159.23, 161.72, 167.52, 152.13, 169.64, 162.56, 154.92, 158.57, 153.17, 159.56, 153.77, 168.02, 157.75, 157.42, 160.65, 160.09, 151.4, 151.05, 136.94, 163.56, 160.39, 146.92, 171.66, 150.48, 158.12, 157.83, 163.99, 164.95]
#
# Son Height = [187.35, 177.8, 181.85, 190.69, 188.07, 168.16, 181.65, 173.94, 174.28, 177.87, 176.01, 185.18, 180.33, 175.85, 178.11, 177.34, 185.46, 173.56, 177.19, 169.02, 157.13, 179.58, 181.05, 169.8, 190.89, 164.82, 175.32, 173.69, 185.73, 185.29]

# %%
FatherHeight = [169.39, 161.91, 159.23, 161.72, 167.52, 152.13, 169.64, 162.56, 154.92, 158.57, 153.17, 159.56, 153.77, 168.02, 157.75, 157.42, 160.65, 160.09, 151.4, 151.05, 136.94, 163.56, 160.39, 146.92, 171.66, 150.48, 158.12, 157.83, 163.99, 164.95]  

SonHeight = [187.35, 177.8, 181.85, 190.69, 188.07, 168.16, 181.65, 173.94, 174.28, 177.87, 176.01, 185.18, 180.33, 175.85, 178.11, 177.34, 185.46, 173.56, 177.19, 169.02, 157.13, 179.58, 181.05, 169.8, 190.89, 164.82, 175.32, 173.69, 185.73, 185.29]

from scipy.stats import pearsonr, spearmanr

p_stat, p_value=pearsonr(FatherHeight,SonHeight)
print(p_stat, p_value)
# Out:
# 0.8002049855103144 1.1121684743613268e-07

# %%
plt.figure(figsize=(6,4))
plt.scatter(FatherHeight,SonHeight, color='b')
plt.title("Father Heights vs. Son Heights")
plt.xlabel("Father Height (cm)")
plt.ylabel("Son Height (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Correct option : 1-c, 2-a,3-b
#
# Explanation :
#
#
# If there is a positive correlation, then based on the trend one can assume/deduce that if the value of one feature is high, then the other also will be high-valued.
# Negative correlation describes when two variables tend to move in the opposite direction from one another, such that when one increases the other variable decreases.
# If there is no correlation between two features, one cannot assume/deduce anything as the points will be scattered all over the plot and will follow no trend(positive or negative).

# %% [markdown]
# A researcher is analyzing the relationship between the number of hours students spend studying and their exam scores. He collects data from 10 students:
#
# study_hours = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
# exam_scores = np.array([60, 65, 70, 75, 80, 85, 90, 95, 100, 105])
#
# Calculate the Pearson correlation coefficient between these variables.

# %%
study_hours = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])  
exam_scores = np.array([60, 65, 70, 75, 80, 85, 90, 95, 100, 105])

p_stat, p_value=pearsonr(study_hours,exam_scores)
print(p_stat, p_value)
# Out:
# 1.0 0.0

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Explanation :
#
# According to Spearman’s rank correlation :
#
# 1) When there are two variables X and Y, if X and Y both increase or decrease simultaneously, then they are strongly positively correlated. The stronger the relationship between them, the more correlated they are.
#
# 2) If when X increases and Y decreases, then those two variables are weakly negatively correlated.
#
# 3) When any of the two variables is not changing (i.e., constant) then there is no relationship between the variables.
#
# We can observe that:
#
# 1. A exhibits a pattern where data points are scattered around a straight line, indicating a positive correlation.
#
# 2. Though a straight line can also be used to show the trend of positive correlation in B, the data points would be farther away from the line on an average, when compared to A.
#
# 3. C consists of a straight line, indicating a correlation approximately equal to 1
#
# 4. In D, we cannot see any increasing or decreasing pattern. We can conclude that Spearman correlation is approximately equal to 0.
#
# Based on this the correct order will be C, A, B, D

# %% [markdown]
# Compute the pearson and spearman correlation between two variables a and b .
#
# a = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
#
# b = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
#
# Select the correct option :

# %%
a = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]

b = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

p_stat, p_value=pearsonr(a,b)
print(p_stat, p_value)
s_stat, s_value=spearmanr(a,b)
print(s_stat, s_value)
# Out:
# 0.8164205163448397 0.0021696288730788035
# 0.8181818181818182 0.0020831448404786904

# %% [markdown]
# A biologist is studying the relationship between the height of plants and the amount of sunlight they receive.
#
# The biologist collects data from 8 different plants, measuring their heights (in centimeters) and ranking them based on the amount of sunlight they receive.
#
#
# plant_heights = np.array([15, 20, 25, 18, 22, 30, 28, 35])
#
# sunlight_rankings = np.array([4, 7, 3, 6, 5, 8, 2, 1])
#
# Calculate the Spearman correlation between these variables.

# %%
plant_heights = np.array([15, 20, 25, 18, 22, 30, 28, 35])

sunlight_rankings = np.array([4, 7, 3, 6, 5, 8, 2, 1])

s_stat, s_value=spearmanr(plant_heights,sunlight_rankings)
print(s_stat, s_value)
# Out:
# -0.3333333333333334 0.4197530864197531

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Correct option: The strength of the linear relationship between the x and y variables
#
# Explanation:
# Correlation coefficients are used to measure how strong a relationship is between two variables.

# %% [markdown]
# Based on the following plots, arrange them in descending order with respect to their correlation values.
#
# a. ![image.png](attachment:image.png)
# b. ![image-2.png](attachment:image-2.png)
# c. ![image-3.png](attachment:image-3.png)
# d. ![image-4.png](attachment:image-4.png)
#
# Ans: ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Correct Answer:There is absolutely no relation between the two variables and it can be concluded that these two variables are completely independent of each other.
#
# Explanation:
#
# There is no relationship or trend between the two variables. In other words, as one variable changes, there is no consistent or predictable change in the other variable.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Correct options :
#
# 1. Pearson gives a measure of strength of linear association between two variables where as Spearman gives a measure of strength of monotonicity between two variables.
# 2. Pearson is calculated from the raw value of data points where as Spearman depends on the rank.
# 3. Both the techniques cannot be used with nominal data
#
# Explanation :
#
# 1. Pearson test tells us the about the slope of the line of best fit. Other than that, Pearson gives a measure of the strength of linear association between two variables whereas Spearman gives a measure of the strength of monotonicity between two variables,
# 2. Pearson coefficient is calculated from the raw value of data points whereas Spearman depends on the rank. It assesses how well the relationship between two variables can be described using a monotonic function.
# 3. Both techniques cannot be used with nominal (unranked) data as the data must be ordinal (ranked) in Spearman.
# 4. the Spearman test does not tell us about the slope of the line of best fit, it tells us how closely our data fit on a line, so two datasets with the same correlation coefficient can have very different slopes.

# %%
# !gdown 1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC
# To: /content/weight-height.csv
# 100% 428k/428k [00:00<00:00, 30.0MB/s]

# %%
df_hw = pd.read_csv("/content/weight-height.csv")

# %%
df_hw.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
sns.scatterplot(x = df_hw["Height"], y = df_hw["Weight"])
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
df = df_hw[["Height" , "Weight"]]
df.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
np.corrcoef(df["Height"], df["Weight"])
# Out:
# array([[1.       , 0.9247563],
#        [0.9247563, 1.       ]])

# %%
from scipy.stats import pearsonr

# H0: No correlation
# Ha: There is a correlation

pearsonr(df_hw["Height"], df_hw["Weight"])
# Out:
# PearsonRResult(statistic=0.9247562987409148, pvalue=0.0)

# %%
from scipy.stats import spearmanr

#H0: No Correlation
#Ha: There is a corrleation

spearmanr(df_hw["Height"], df_hw["Weight"])
# Out:
# SignificanceResult(statistic=0.9257076644210767, pvalue=0.0)

# %%
#Quiz2:

'''
Given two arrays X and Y.
Find Spearman’s Rank Correlation
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
'''
from scipy.stats import spearmanr
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]

corr, pval = spearmanr(x, y)

print(corr)
# Out:
# -0.9999999999999999

# %%
'''
Quiz3:

Given two arrays X and Y.
Find Pearson correlation coefficient
x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]

'''


x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]

corr, pval = pearsonr(x,y)

print(corr)
# Out:
# -0.8285038835884277
